# %%
import cfbd
from cfbd.rest import ApiException
import pandas as pd
import sqlite3

# %%
# def extract_team_data(year,week):
#     """
#     Extracts team statistics from a list of game data and converts it into a DataFrame.
    
#     This function processes each game in the provided list, extracts information about each team,
#     including their IDs, names, home/away status, points scored, and other statistical categories.
#     The resulting data is then normalized into a DataFrame for easier analysis.
    
#     :param game_data: List of game objects, where each game object contains details about the game
#                       and its participating teams.
#     :return: DataFrame containing extracted team statistics for each game.
#     """
#     game_stats=[] # Initialize a list to store statistics for each team
   
#     game_data = api_instance.get_team_game_stats(year=year, week=week)
#     for game in game_data:
#         game_id=game.id # Extract the unique identifier for the game
#         teams=game.teams # Get the list of teams involved in the game
        
#         # Iterate through each team in the game
#         for team in teams:
#             team_id = team.school_id # Extract the unique identifier for the team
#             team_name = team.school # Extract the name of the team
#             home_away = team.home_away # Determine if the team is playing at home or away

#             team_stats = {
#                 'game_id': game_id,
#                 'team_id': team_id,
#                 'team_name': team_name,
#                 'home_away': home_away,
#                 'points': team.points # Extract the points scored by the team
#                 }
#                 # Add stats to the dictionary
#             for stat in team.stats:
#                 category = stat.category
#                 value = stat.stat
#                 team_stats[category] = value
#                 # Append the team's stats to the list of game statistics
#             game_stats.append(team_stats)
#     # Concatenate the weekly data into the final DataFrame
#     return pd.json_normalize(game_stats)

# %%
# api_instance.get_team_game_stats(year=2023, week=1)
# Out:
# [{'id': 401540244,
#   'teams': [{'conference': 'Southland',
#              'home_away': 'home',
#              'points': 17,
#              'school': 'Lamar',
#              'school_id': 2320,
#              'stats': [{'category': 'rushingTDs', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '82'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '4'},
#                        {'category': 'kickingPoints', 'stat': '5'},
#                        {'category': 'interceptionYards', 'stat': '0'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '1'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'possessionTime', 'stat': '29:44'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '5-35'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '2.3'},
#                        {'category': 'rushingAttempts', 'stat': '31'},
#                        {'category': 'rushingYards', 'stat': '71'},
#                        {'category': 'yardsPerPass', 'stat': '5.0'},
#                        {'category': 'completionAttempts', 'stat': '15-24'},
#                        {'category': 'netPassingYards', 'stat': '119'},
#                        {'category': 'totalYards', 'stat': '190'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '6-13'},
#                        {'category': 'firstDowns', 'stat': '16'}]},
#             {'conference': 'Big Sky',
#              'home_away': 'away',
#              'points': 42,
#              'school': 'Idaho',
#              'school_id': 70,
#              'stats': [{'category': 'rushingTDs', 'stat': '2'},
#                        {'category': 'puntReturnYards', 'stat': '26'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '3'},
#                        {'category': 'passingTDs', 'stat': '4'},
#                        {'category': 'kickReturnYards', 'stat': '0'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '4'},
#                        {'category': 'interceptionYards', 'stat': '13'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '3'},
#                        {'category': 'possessionTime', 'stat': '30:16'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '1'},
#                        {'category': 'turnovers', 'stat': '2'},
#                        {'category': 'totalPenaltiesYards', 'stat': '8-101'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '7.6'},
#                        {'category': 'rushingAttempts', 'stat': '36'},
#                        {'category': 'rushingYards', 'stat': '273'},
#                        {'category': 'yardsPerPass', 'stat': '10.7'},
#                        {'category': 'completionAttempts', 'stat': '16-21'},
#                        {'category': 'netPassingYards', 'stat': '224'},
#                        {'category': 'totalYards', 'stat': '497'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '6-9'},
#                        {'category': 'firstDowns', 'stat': '20'}]}]},
#  {'id': 401525434,
#   'teams': [{'conference': 'American Athletic',
#              'home_away': 'away',
#              'points': 3,
#              'school': 'Navy',
#              'school_id': 2426,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'passingTDs', 'stat': '0'},
#                        {'category': 'kickReturnYards', 'stat': '12'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '3'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '3'},
#                        {'category': 'tacklesForLoss', 'stat': '2'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '42'},
#                        {'category': 'sacks', 'stat': '0'},
#                        {'category': 'qbHurries', 'stat': '1'},
#                        {'category': 'passesDeflected', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '33:14'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '3-26'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '2.6'},
#                        {'category': 'rushingAttempts', 'stat': '48'},
#                        {'category': 'rushingYards', 'stat': '126'},
#                        {'category': 'yardsPerPass', 'stat': '6.1'},
#                        {'category': 'completionAttempts', 'stat': '3-7'},
#                        {'category': 'netPassingYards', 'stat': '43'},
#                        {'category': 'totalYards', 'stat': '169'},
#                        {'category': 'fourthDownEff', 'stat': '3-4'},
#                        {'category': 'thirdDownEff', 'stat': '4-14'},
#                        {'category': 'firstDowns', 'stat': '12'}]},
#             {'conference': 'FBS Independents',
#              'home_away': 'home',
#              'points': 42,
#              'school': 'Notre Dame',
#              'school_id': 87,
#              'stats': [{'category': 'rushingTDs', 'stat': '2'},
#                        {'category': 'puntReturnYards', 'stat': '11'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '4'},
#                        {'category': 'kickReturnYards', 'stat': '41'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '6'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '2'},
#                        {'category': 'tacklesForLoss', 'stat': '5'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '41'},
#                        {'category': 'sacks', 'stat': '2'},
#                        {'category': 'qbHurries', 'stat': '2'},
#                        {'category': 'passesDeflected', 'stat': '0'},
#                        {'category': 'possessionTime', 'stat': '26:46'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '1-10'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '6.0'},
#                        {'category': 'rushingAttempts', 'stat': '32'},
#                        {'category': 'rushingYards', 'stat': '191'},
#                        {'category': 'yardsPerPass', 'stat': '10.1'},
#                        {'category': 'completionAttempts', 'stat': '20-25'},
#                        {'category': 'netPassingYards', 'stat': '253'},
#                        {'category': 'totalYards', 'stat': '444'},
#                        {'category': 'fourthDownEff', 'stat': '1-1'},
#                        {'category': 'thirdDownEff', 'stat': '5-7'},
#                        {'category': 'firstDowns', 'stat': '27'}]}]},
#  {'id': 401525435,
#   'teams': [{'conference': 'Big South-OVC',
#              'home_away': 'away',
#              'points': 3,
#              'school': 'Tennessee State',
#              'school_id': 2634,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'passingTDs', 'stat': '0'},
#                        {'category': 'kickReturnYards', 'stat': '76'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '3'},
#                        {'category': 'fumblesRecovered', 'stat': '1'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '6'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '45'},
#                        {'category': 'sacks', 'stat': '0'},
#                        {'category': 'qbHurries', 'stat': '1'},
#                        {'category': 'passesDeflected', 'stat': '1'},
#                        {'category': 'possessionTime', 'stat': '26:16'},
#                        {'category': 'interceptions', 'stat': '2'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '2'},
#                        {'category': 'totalPenaltiesYards', 'stat': '5-45'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '2.6'},
#                        {'category': 'rushingAttempts', 'stat': '35'},
#                        {'category': 'rushingYards', 'stat': '91'},
#                        {'category': 'yardsPerPass', 'stat': '3.0'},
#                        {'category': 'completionAttempts', 'stat': '8-22'},
#                        {'category': 'netPassingYards', 'stat': '67'},
#                        {'category': 'totalYards', 'stat': '158'},
#                        {'category': 'fourthDownEff', 'stat': '1-1'},
#                        {'category': 'thirdDownEff', 'stat': '4-14'},
#                        {'category': 'firstDowns', 'stat': '12'}]},
#             {'conference': 'FBS Independents',
#              'home_away': 'home',
#              'points': 56,
#              'school': 'Notre Dame',
#              'school_id': 87,
#              'stats': [{'category': 'rushingTDs', 'stat': '3'},
#                        {'category': 'puntReturnYards', 'stat': '27'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '3'},
#                        {'category': 'passingTDs', 'stat': '4'},
#                        {'category': 'kickReturnYards', 'stat': '8'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '8'},
#                        {'category': 'interceptionYards', 'stat': '33'},
#                        {'category': 'interceptionTDs', 'stat': '1'},
#                        {'category': 'passesIntercepted', 'stat': '2'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '5'},
#                        {'category': 'defensiveTDs', 'stat': '1'},
#                        {'category': 'tackles', 'stat': '32'},
#                        {'category': 'sacks', 'stat': '1'},
#                        {'category': 'qbHurries', 'stat': '10'},
#                        {'category': 'passesDeflected', 'stat': '4'},
#                        {'category': 'possessionTime', 'stat': '33:44'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '1'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '4-36'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '6.7'},
#                        {'category': 'rushingAttempts', 'stat': '33'},
#                        {'category': 'rushingYards', 'stat': '221'},
#                        {'category': 'yardsPerPass', 'stat': '11.2'},
#                        {'category': 'completionAttempts', 'stat': '24-30'},
#                        {'category': 'netPassingYards', 'stat': '336'},
#                        {'category': 'totalYards', 'stat': '557'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '9-11'},
#                        {'category': 'firstDowns', 'stat': '26'}]}]},
#  {'id': 401520154,
#   'teams': [{'conference': 'Big South-OVC',
#              'home_away': 'away',
#              'points': 7,
#              'school': 'UT Martin',
#              'school_id': 2630,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '7'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '4'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '45'},
#                        {'category': 'sacks', 'stat': '0'},
#                        {'category': 'qbHurries', 'stat': '0'},
#                        {'category': 'passesDeflected', 'stat': '3'},
#                        {'category': 'possessionTime', 'stat': '29:35'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '10-72'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '4.6'},
#                        {'category': 'rushingAttempts', 'stat': '29'},
#                        {'category': 'rushingYards', 'stat': '134'},
#                        {'category': 'yardsPerPass', 'stat': '3.9'},
#                        {'category': 'completionAttempts', 'stat': '18-33'},
#                        {'category': 'netPassingYards', 'stat': '128'},
#                        {'category': 'totalYards', 'stat': '262'},
#                        {'category': 'fourthDownEff', 'stat': '1-1'},
#                        {'category': 'thirdDownEff', 'stat': '2-14'},
#                        {'category': 'firstDowns', 'stat': '15'}]},
#             {'conference': 'SEC',
#              'home_away': 'home',
#              'points': 48,
#              'school': 'Georgia',
#              'school_id': 61,
#              'stats': [{'category': 'rushingTDs', 'stat': '3'},
#                        {'category': 'puntReturnYards', 'stat': '19'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '2'},
#                        {'category': 'kickReturnYards', 'stat': '31'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '12'},
#                        {'category': 'interceptionYards', 'stat': '26'},
#                        {'category': 'interceptionTDs', 'stat': '1'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '4'},
#                        {'category': 'defensiveTDs', 'stat': '1'},
#                        {'category': 'tackles', 'stat': '28'},
#                        {'category': 'sacks', 'stat': '1'},
#                        {'category': 'qbHurries', 'stat': '0'},
#                        {'category': 'passesDeflected', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '30:25'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '5-42'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '5.3'},
#                        {'category': 'rushingAttempts', 'stat': '30'},
#                        {'category': 'rushingYards', 'stat': '159'},
#                        {'category': 'yardsPerPass', 'stat': '10.3'},
#                        {'category': 'completionAttempts', 'stat': '26-39'},
#                        {'category': 'netPassingYards', 'stat': '400'},
#                        {'category': 'totalYards', 'stat': '559'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '5-12'},
#                        {'category': 'firstDowns', 'stat': '28'}]}]},
#  {'id': 401520176,
#   'teams': [{'conference': 'Pac-12',
#              'home_away': 'home',
#              'points': 24,
#              'school': 'Utah',
#              'school_id': 254,
#              'stats': [{'category': 'rushingTDs', 'stat': '2'},
#                        {'category': 'puntReturnYards', 'stat': '5'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '3'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '16'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '6'},
#                        {'category': 'interceptionYards', 'stat': '2'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '7'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '37'},
#                        {'category': 'sacks', 'stat': '5'},
#                        {'category': 'qbHurries', 'stat': '0'},
#                        {'category': 'passesDeflected', 'stat': '4'},
#                        {'category': 'possessionTime', 'stat': '28:08'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '5-37'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '3.5'},
#                        {'category': 'rushingAttempts', 'stat': '30'},
#                        {'category': 'rushingYards', 'stat': '105'},
#                        {'category': 'yardsPerPass', 'stat': '7.2'},
#                        {'category': 'completionAttempts', 'stat': '15-23'},
#                        {'category': 'netPassingYards', 'stat': '165'},
#                        {'category': 'totalYards', 'stat': '270'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '3-13'},
#                        {'category': 'firstDowns', 'stat': '14'}]},
#             {'conference': 'SEC',
#              'home_away': 'away',
#              'points': 11,
#              'school': 'Florida',
#              'school_id': 57,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'puntReturnYards', 'stat': '5'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '47'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '3'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '4'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '29'},
#                        {'category': 'sacks', 'stat': '0'},
#                        {'category': 'qbHurries', 'stat': '2'},
#                        {'category': 'passesDeflected', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '31:52'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '9-46'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '0.6'},
#                        {'category': 'rushingAttempts', 'stat': '21'},
#                        {'category': 'rushingYards', 'stat': '13'},
#                        {'category': 'yardsPerPass', 'stat': '7.6'},
#                        {'category': 'completionAttempts', 'stat': '31-44'},
#                        {'category': 'netPassingYards', 'stat': '333'},
#                        {'category': 'totalYards', 'stat': '346'},
#                        {'category': 'fourthDownEff', 'stat': '2-5'},
#                        {'category': 'thirdDownEff', 'stat': '1-13'},
#                        {'category': 'firstDowns', 'stat': '17'}]}]},
#  {'id': 401520179,
#   'teams': [{'conference': 'ACC',
#              'home_away': 'away',
#              'points': 13,
#              'school': 'Virginia',
#              'school_id': 258,
#              'stats': [{'category': 'rushingTDs', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '0'},
#                        {'category': 'kickReturnYards', 'stat': '21'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '7'},
#                        {'category': 'fumblesRecovered', 'stat': '1'},
#                        {'category': 'totalFumbles', 'stat': '0'},
#                        {'category': 'tacklesForLoss', 'stat': '1'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '54'},
#                        {'category': 'sacks', 'stat': '1'},
#                        {'category': 'qbHurries', 'stat': '0'},
#                        {'category': 'passesDeflected', 'stat': '5'},
#                        {'category': 'possessionTime', 'stat': '32:54'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '2-10'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '2.4'},
#                        {'category': 'rushingAttempts', 'stat': '40'},
#                        {'category': 'rushingYards', 'stat': '95'},
#                        {'category': 'yardsPerPass', 'stat': '4.4'},
#                        {'category': 'completionAttempts', 'stat': '11-24'},
#                        {'category': 'netPassingYards', 'stat': '106'},
#                        {'category': 'totalYards', 'stat': '201'},
#                        {'category': 'fourthDownEff', 'stat': '0-1'},
#                        {'category': 'thirdDownEff', 'stat': '5-18'},
#                        {'category': 'firstDowns', 'stat': '12'}]},
#             {'conference': 'SEC',
#              'home_away': 'home',
#              'points': 49,
#              'school': 'Tennessee',
#              'school_id': 2633,
#              'stats': [{'category': 'rushingTDs', 'stat': '5'},
#                        {'category': 'puntReturnYards', 'stat': '105'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '3'},
#                        {'category': 'passingTDs', 'stat': '2'},
#                        {'category': 'kickReturnYards', 'stat': '34'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '7'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '11'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '32'},
#                        {'category': 'sacks', 'stat': '4'},
#                        {'category': 'qbHurries', 'stat': '2'},
#                        {'category': 'passesDeflected', 'stat': '5'},
#                        {'category': 'possessionTime', 'stat': '27:06'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '1'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '4-35'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '5.5'},
#                        {'category': 'rushingAttempts', 'stat': '52'},
#                        {'category': 'rushingYards', 'stat': '287'},
#                        {'category': 'yardsPerPass', 'stat': '6.4'},
#                        {'category': 'completionAttempts', 'stat': '23-33'},
#                        {'category': 'netPassingYards', 'stat': '212'},
#                        {'category': 'totalYards', 'stat': '499'},
#                        {'category': 'fourthDownEff', 'stat': '2-3'},
#                        {'category': 'thirdDownEff', 'stat': '5-13'},
#                        {'category': 'firstDowns', 'stat': '29'}]}]},
#  {'id': 401520167,
#   'teams': [{'conference': 'ACC',
#              'home_away': 'home',
#              'points': 31,
#              'school': 'North Carolina',
#              'school_id': 153,
#              'stats': [{'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'rushingTDs', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '2'},
#                        {'category': 'kickReturnYards', 'stat': '16'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '7'},
#                        {'category': 'tacklesForLoss', 'stat': '16'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '46'},
#                        {'category': 'sacks', 'stat': '9'},
#                        {'category': 'qbHurries', 'stat': '0'},
#                        {'category': 'passesDeflected', 'stat': '1'},
#                        {'category': 'possessionTime', 'stat': '32:37'},
#                        {'category': 'interceptions', 'stat': '2'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '2'},
#                        {'category': 'totalPenaltiesYards', 'stat': '7-49'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '4.3'},
#                        {'category': 'rushingAttempts', 'stat': '39'},
#                        {'category': 'rushingYards', 'stat': '168'},
#                        {'category': 'yardsPerPass', 'stat': '8.4'},
#                        {'category': 'completionAttempts', 'stat': '24-32'},
#                        {'category': 'netPassingYards', 'stat': '269'},
#                        {'category': 'totalYards', 'stat': '437'},
#                        {'category': 'fourthDownEff', 'stat': '1-2'},
#                        {'category': 'thirdDownEff', 'stat': '8-13'},
#                        {'category': 'firstDowns', 'stat': '21'}]},
#             {'conference': 'SEC',
#              'home_away': 'away',
#              'points': 17,
#              'school': 'South Carolina',
#              'school_id': 2579,
#              'stats': [{'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'rushingTDs', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '0'},
#                        {'category': 'kickReturnYards', 'stat': '43'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '5'},
#                        {'category': 'interceptionYards', 'stat': '22'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '2'},
#                        {'category': 'tacklesForLoss', 'stat': '1'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '32'},
#                        {'category': 'sacks', 'stat': '0'},
#                        {'category': 'qbHurries', 'stat': '2'},
#                        {'category': 'passesDeflected', 'stat': '1'},
#                        {'category': 'possessionTime', 'stat': '27:23'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '6-35'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '-0.1'},
#                        {'category': 'rushingAttempts', 'stat': '31'},
#                        {'category': 'rushingYards', 'stat': '-2'},
#                        {'category': 'yardsPerPass', 'stat': '9.1'},
#                        {'category': 'completionAttempts', 'stat': '30-39'},
#                        {'category': 'netPassingYards', 'stat': '353'},
#                        {'category': 'totalYards', 'stat': '351'},
#                        {'category': 'fourthDownEff', 'stat': '0-4'},
#                        {'category': 'thirdDownEff', 'stat': '4-14'},
#                        {'category': 'firstDowns', 'stat': '20'}]}]},
#  {'id': 401520159,
#   'teams': [{'conference': 'Mid-American',
#              'home_away': 'away',
#              'points': 14,
#              'school': 'Ball State',
#              'school_id': 2050,
#              'stats': [{'category': 'rushingTDs', 'stat': '1'},
#                        {'category': 'puntReturnYards', 'stat': '3'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '2'},
#                        {'category': 'interceptionYards', 'stat': '0'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '3'},
#                        {'category': 'tacklesForLoss', 'stat': '3'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '27'},
#                        {'category': 'sacks', 'stat': '1'},
#                        {'category': 'qbHurries', 'stat': '2'},
#                        {'category': 'passesDeflected', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '38:16'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '2'},
#                        {'category': 'turnovers', 'stat': '2'},
#                        {'category': 'totalPenaltiesYards', 'stat': '4-26'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '1.8'},
#                        {'category': 'rushingAttempts', 'stat': '41'},
#                        {'category': 'rushingYards', 'stat': '72'},
#                        {'category': 'yardsPerPass', 'stat': '7.4'},
#                        {'category': 'completionAttempts', 'stat': '22-30'},
#                        {'category': 'netPassingYards', 'stat': '223'},
#                        {'category': 'totalYards', 'stat': '295'},
#                        {'category': 'fourthDownEff', 'stat': '1-2'},
#                        {'category': 'thirdDownEff', 'stat': '9-17'},
#                        {'category': 'firstDowns', 'stat': '18'}]},
#             {'conference': 'SEC',
#              'home_away': 'home',
#              'points': 44,
#              'school': 'Kentucky',
#              'school_id': 96,
#              'stats': [{'category': 'rushingTDs', 'stat': '2'},
#                        {'category': 'puntReturnYards', 'stat': '27'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '117'},
#                        {'category': 'kickReturnTDs', 'stat': '1'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '14'},
#                        {'category': 'fumblesRecovered', 'stat': '2'},
#                        {'category': 'totalFumbles', 'stat': '0'},
#                        {'category': 'tacklesForLoss', 'stat': '8'},
#                        {'category': 'defensiveTDs', 'stat': '1'},
#                        {'category': 'tackles', 'stat': '44'},
#                        {'category': 'sacks', 'stat': '3'},
#                        {'category': 'qbHurries', 'stat': '1'},
#                        {'category': 'passesDeflected', 'stat': '1'},
#                        {'category': 'possessionTime', 'stat': '21:44'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '7-51'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '5.7'},
#                        {'category': 'rushingAttempts', 'stat': '20'},
#                        {'category': 'rushingYards', 'stat': '113'},
#                        {'category': 'yardsPerPass', 'stat': '7.8'},
#                        {'category': 'completionAttempts', 'stat': '18-31'},
#                        {'category': 'netPassingYards', 'stat': '241'},
#                        {'category': 'totalYards', 'stat': '354'},
#                        {'category': 'fourthDownEff', 'stat': '0-1'},
#                        {'category': 'thirdDownEff', 'stat': '4-9'},
#                        {'category': 'firstDowns', 'stat': '17'}]}]},
#  {'id': 401520147,
#   'teams': [{'conference': 'Mountain West',
#              'home_away': 'away',
#              'points': 28,
#              'school': "Hawai'i",
#              'school_id': 62,
#              'stats': [{'category': 'rushingTDs', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '3'},
#                        {'category': 'kickReturnYards', 'stat': '90'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '4'},
#                        {'category': 'kickingPoints', 'stat': '4'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '9'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '35'},
#                        {'category': 'sacks', 'stat': '3'},
#                        {'category': 'qbHurries', 'stat': '2'},
#                        {'category': 'passesDeflected', 'stat': '6'},
#                        {'category': 'possessionTime', 'stat': '31:22'},
#                        {'category': 'interceptions', 'stat': '2'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '2'},
#                        {'category': 'totalPenaltiesYards', 'stat': '7-59'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '1.6'},
#                        {'category': 'rushingAttempts', 'stat': '25'},
#                        {'category': 'rushingYards', 'stat': '40'},
#                        {'category': 'yardsPerPass', 'stat': '10.0'},
#                        {'category': 'completionAttempts', 'stat': '27-35'},
#                        {'category': 'netPassingYards', 'stat': '351'},
#                        {'category': 'totalYards', 'stat': '391'},
#                        {'category': 'fourthDownEff', 'stat': '3-4'},
#                        {'category': 'thirdDownEff', 'stat': '3-11'},
#                        {'category': 'firstDowns', 'stat': '19'}]},
#             {'conference': 'SEC',
#              'home_away': 'home',
#              'points': 35,
#              'school': 'Vanderbilt',
#              'school_id': 238,
#              'stats': [{'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'rushingTDs', 'stat': '1'},
#                        {'category': 'puntReturnYards', 'stat': '27'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '3'},
#                        {'category': 'kickReturnYards', 'stat': '97'},
#                        {'category': 'kickReturnTDs', 'stat': '1'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '3'},
#                        {'category': 'interceptionYards', 'stat': '9'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '2'},
#                        {'category': 'tacklesForLoss', 'stat': '8'},
#                        {'category': 'defensiveTDs', 'stat': '1'},
#                        {'category': 'tackles', 'stat': '37'},
#                        {'category': 'sacks', 'stat': '3'},
#                        {'category': 'qbHurries', 'stat': '4'},
#                        {'category': 'passesDeflected', 'stat': '4'},
#                        {'category': 'possessionTime', 'stat': '28:38'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '8-72'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '1.5'},
#                        {'category': 'rushingAttempts', 'stat': '26'},
#                        {'category': 'rushingYards', 'stat': '39'},
#                        {'category': 'yardsPerPass', 'stat': '8.6'},
#                        {'category': 'completionAttempts', 'stat': '19-30'},
#                        {'category': 'netPassingYards', 'stat': '258'},
#                        {'category': 'totalYards', 'stat': '297'},
#                        {'category': 'fourthDownEff', 'stat': '1-3'},
#                        {'category': 'thirdDownEff', 'stat': '5-12'},
#                        {'category': 'firstDowns', 'stat': '17'}]}]},
#  {'id': 401520178,
#   'teams': [{'conference': 'SWAC',
#              'home_away': 'away',
#              'points': 13,
#              'school': 'Alabama A&M',
#              'school_id': 2010,
#              'stats': [{'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '50'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '3'},
#                        {'category': 'kickingPoints', 'stat': '7'},
#                        {'category': 'interceptionYards', 'stat': '8'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '4'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '37'},
#                        {'category': 'sacks', 'stat': '1'},
#                        {'category': 'qbHurries', 'stat': '1'},
#                        {'category': 'passesDeflected', 'stat': '6'},
#                        {'category': 'possessionTime', 'stat': '32:22'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '9-50'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '4.1'},
#                        {'category': 'rushingAttempts', 'stat': '33'},
#                        {'category': 'rushingYards', 'stat': '135'},
#                        {'category': 'yardsPerPass', 'stat': '4.2'},
#                        {'category': 'completionAttempts', 'stat': '18-34'},
#                        {'category': 'netPassingYards', 'stat': '143'},
#                        {'category': 'totalYards', 'stat': '278'},
#                        {'category': 'fourthDownEff', 'stat': '1-1'},
#                        {'category': 'thirdDownEff', 'stat': '6-18'},
#                        {'category': 'firstDowns', 'stat': '14'}]},
#             {'conference': 'SEC',
#              'home_away': 'home',
#              'points': 47,
#              'school': 'Vanderbilt',
#              'school_id': 238,
#              'stats': [{'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'rushingTDs', 'stat': '3'},
#                        {'category': 'puntReturnYards', 'stat': '96'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '6'},
#                        {'category': 'passingTDs', 'stat': '3'},
#                        {'category': 'kickReturnYards', 'stat': '69'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '3'},
#                        {'category': 'kickingPoints', 'stat': '9'},
#                        {'category': 'interceptionYards', 'stat': '5'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '7'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '30'},
#                        {'category': 'sacks', 'stat': '2'},
#                        {'category': 'qbHurries', 'stat': '3'},
#                        {'category': 'passesDeflected', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '27:38'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '3-20'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '6.3'},
#                        {'category': 'rushingAttempts', 'stat': '34'},
#                        {'category': 'rushingYards', 'stat': '215'},
#                        {'category': 'yardsPerPass', 'stat': '7.9'},
#                        {'category': 'completionAttempts', 'stat': '17-31'},
#                        {'category': 'netPassingYards', 'stat': '246'},
#                        {'category': 'totalYards', 'stat': '461'},
#                        {'category': 'fourthDownEff', 'stat': '0-1'},
#                        {'category': 'thirdDownEff', 'stat': '9-14'},
#                        {'category': 'firstDowns', 'stat': '24'}]}]},
#  {'id': 401525823,
#   'teams': [{'conference': 'UAC',
#              'home_away': 'away',
#              'points': 13,
#              'school': 'Central Arkansas',
#              'school_id': 2110,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'puntReturnYards', 'stat': '5'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '2'},
#                        {'category': 'kickReturnYards', 'stat': '31'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '1'},
#                        {'category': 'interceptionYards', 'stat': '0'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '4'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '35'},
#                        {'category': 'sacks', 'stat': '1'},
#                        {'category': 'qbHurries', 'stat': '4'},
#                        {'category': 'passesDeflected', 'stat': '3'},
#                        {'category': 'possessionTime', 'stat': '27:30'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '1'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '9-63'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '4.4'},
#                        {'category': 'rushingAttempts', 'stat': '28'},
#                        {'category': 'rushingYards', 'stat': '123'},
#                        {'category': 'yardsPerPass', 'stat': '7.2'},
# ...
#                        {'category': 'yardsPerPass', 'stat': '8.3'},
#                        {'category': 'completionAttempts', 'stat': '22-36'},
#                        {'category': 'netPassingYards', 'stat': '300'},
#                        {'category': 'totalYards', 'stat': '458'},
#                        {'category': 'fourthDownEff', 'stat': '1-3'},
#                        {'category': 'thirdDownEff', 'stat': '6-15'},
#                        {'category': 'firstDowns', 'stat': '24'}]},
#             {'conference': 'American Athletic',
#              'home_away': 'away',
#              'points': 10,
#              'school': 'Rice',
#              'school_id': 242,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '26'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '4'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'possessionTime', 'stat': '28:24'},
#                        {'category': 'interceptions', 'stat': '2'},
#                        {'category': 'fumblesLost', 'stat': '1'},
#                        {'category': 'turnovers', 'stat': '3'},
#                        {'category': 'totalPenaltiesYards', 'stat': '5-25'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '1.1'},
#                        {'category': 'rushingAttempts', 'stat': '25'},
#                        {'category': 'rushingYards', 'stat': '27'},
#                        {'category': 'yardsPerPass', 'stat': '5.7'},
#                        {'category': 'completionAttempts', 'stat': '14-26'},
#                        {'category': 'netPassingYards', 'stat': '149'},
#                        {'category': 'totalYards', 'stat': '176'},
#                        {'category': 'fourthDownEff', 'stat': '1-2'},
#                        {'category': 'thirdDownEff', 'stat': '4-13'},
#                        {'category': 'firstDowns', 'stat': '8'}]}]},
#  {'id': 401520158,
#   'teams': [{'conference': 'Southern',
#              'home_away': 'away',
#              'points': 3,
#              'school': 'East Tennessee State',
#              'school_id': 2193,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'passingTDs', 'stat': '0'},
#                        {'category': 'kickReturnYards', 'stat': '46'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '3'},
#                        {'category': 'kickingPoints', 'stat': '3'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '3'},
#                        {'category': 'tacklesForLoss', 'stat': '4'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '42'},
#                        {'category': 'sacks', 'stat': '1'},
#                        {'category': 'qbHurries', 'stat': '3'},
#                        {'category': 'passesDeflected', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '29:17'},
#                        {'category': 'interceptions', 'stat': '2'},
#                        {'category': 'fumblesLost', 'stat': '2'},
#                        {'category': 'turnovers', 'stat': '4'},
#                        {'category': 'totalPenaltiesYards', 'stat': '9-88'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '2.3'},
#                        {'category': 'rushingAttempts', 'stat': '38'},
#                        {'category': 'rushingYards', 'stat': '87'},
#                        {'category': 'yardsPerPass', 'stat': '6.5'},
#                        {'category': 'completionAttempts', 'stat': '10-18'},
#                        {'category': 'netPassingYards', 'stat': '117'},
#                        {'category': 'totalYards', 'stat': '204'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '1-11'},
#                        {'category': 'firstDowns', 'stat': '12'}]},
#             {'conference': 'Conference USA',
#              'home_away': 'home',
#              'points': 49,
#              'school': 'Jacksonville State',
#              'school_id': 55,
#              'stats': [{'category': 'rushingTDs', 'stat': '6'},
#                        {'category': 'puntReturnYards', 'stat': '16'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '7'},
#                        {'category': 'interceptionYards', 'stat': '32'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '2'},
#                        {'category': 'fumblesRecovered', 'stat': '2'},
#                        {'category': 'totalFumbles', 'stat': '3'},
#                        {'category': 'tacklesForLoss', 'stat': '8'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '25'},
#                        {'category': 'sacks', 'stat': '3'},
#                        {'category': 'qbHurries', 'stat': '5'},
#                        {'category': 'passesDeflected', 'stat': '1'},
#                        {'category': 'possessionTime', 'stat': '30:43'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '0'},
#                        {'category': 'totalPenaltiesYards', 'stat': '7-65'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '4.2'},
#                        {'category': 'rushingAttempts', 'stat': '56'},
#                        {'category': 'rushingYards', 'stat': '237'},
#                        {'category': 'yardsPerPass', 'stat': '6.7'},
#                        {'category': 'completionAttempts', 'stat': '13-19'},
#                        {'category': 'netPassingYards', 'stat': '127'},
#                        {'category': 'totalYards', 'stat': '364'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '7-13'},
#                        {'category': 'firstDowns', 'stat': '25'}]}]},
#  {'id': 401540354,
#   'teams': [{'conference': None,
#              'home_away': 'away',
#              'points': 0,
#              'school': 'Arkansas Baptist',
#              'school_id': 124386,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'puntReturnYards', 'stat': '-2'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '0'},
#                        {'category': 'kickReturnYards', 'stat': '131'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '6'},
#                        {'category': 'kickingPoints', 'stat': '0'},
#                        {'category': 'fumblesRecovered', 'stat': '2'},
#                        {'category': 'totalFumbles', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '36:41'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '2'},
#                        {'category': 'turnovers', 'stat': '3'},
#                        {'category': 'totalPenaltiesYards', 'stat': '9-70'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '1.6'},
#                        {'category': 'rushingAttempts', 'stat': '53'},
#                        {'category': 'rushingYards', 'stat': '85'},
#                        {'category': 'yardsPerPass', 'stat': '2.9'},
#                        {'category': 'completionAttempts', 'stat': '6-16'},
#                        {'category': 'netPassingYards', 'stat': '47'},
#                        {'category': 'totalYards', 'stat': '132'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '6-20'},
#                        {'category': 'firstDowns', 'stat': '10'}]},
#             {'conference': 'Southland',
#              'home_away': 'home',
#              'points': 66,
#              'school': 'Houston Christian',
#              'school_id': 2277,
#              'stats': [{'category': 'rushingTDs', 'stat': '5'},
#                        {'category': 'puntReturnYards', 'stat': '49'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '4'},
#                        {'category': 'passingTDs', 'stat': '3'},
#                        {'category': 'kickReturnYards', 'stat': '17'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '1'},
#                        {'category': 'kickingPoints', 'stat': '12'},
#                        {'category': 'interceptionYards', 'stat': '16'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '2'},
#                        {'category': 'totalFumbles', 'stat': '2'},
#                        {'category': 'possessionTime', 'stat': '23:19'},
#                        {'category': 'interceptions', 'stat': '0'},
#                        {'category': 'fumblesLost', 'stat': '2'},
#                        {'category': 'turnovers', 'stat': '2'},
#                        {'category': 'totalPenaltiesYards', 'stat': '8-55'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '6.9'},
#                        {'category': 'rushingAttempts', 'stat': '35'},
#                        {'category': 'rushingYards', 'stat': '242'},
#                        {'category': 'yardsPerPass', 'stat': '11.6'},
#                        {'category': 'completionAttempts', 'stat': '16-20'},
#                        {'category': 'netPassingYards', 'stat': '232'},
#                        {'category': 'totalYards', 'stat': '474'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '3-8'},
#                        {'category': 'firstDowns', 'stat': '20'}]}]},
#  {'id': 401520148,
#   'teams': [{'conference': 'Big Ten',
#              'home_away': 'away',
#              'points': 10,
#              'school': 'Nebraska',
#              'school_id': 158,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'puntReturnYards', 'stat': '8'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '2'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '78'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '2'},
#                        {'category': 'kickingPoints', 'stat': '4'},
#                        {'category': 'interceptionYards', 'stat': '0'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '1'},
#                        {'category': 'fumblesRecovered', 'stat': '0'},
#                        {'category': 'totalFumbles', 'stat': '1'},
#                        {'category': 'tacklesForLoss', 'stat': '5'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '36'},
#                        {'category': 'sacks', 'stat': '3'},
#                        {'category': 'qbHurries', 'stat': '3'},
#                        {'category': 'passesDeflected', 'stat': '4'},
#                        {'category': 'possessionTime', 'stat': '29:18'},
#                        {'category': 'interceptions', 'stat': '3'},
#                        {'category': 'fumblesLost', 'stat': '1'},
#                        {'category': 'turnovers', 'stat': '4'},
#                        {'category': 'totalPenaltiesYards', 'stat': '7-55'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '4.9'},
#                        {'category': 'rushingAttempts', 'stat': '37'},
#                        {'category': 'rushingYards', 'stat': '181'},
#                        {'category': 'yardsPerPass', 'stat': '6.0'},
#                        {'category': 'completionAttempts', 'stat': '11-19'},
#                        {'category': 'netPassingYards', 'stat': '114'},
#                        {'category': 'totalYards', 'stat': '295'},
#                        {'category': 'fourthDownEff', 'stat': '0-0'},
#                        {'category': 'thirdDownEff', 'stat': '5-11'},
#                        {'category': 'firstDowns', 'stat': '18'}]},
#             {'conference': 'Big Ten',
#              'home_away': 'home',
#              'points': 13,
#              'school': 'Minnesota',
#              'school_id': 135,
#              'stats': [{'category': 'rushingTDs', 'stat': '0'},
#                        {'category': 'puntReturnYards', 'stat': '10'},
#                        {'category': 'puntReturnTDs', 'stat': '0'},
#                        {'category': 'puntReturns', 'stat': '1'},
#                        {'category': 'passingTDs', 'stat': '1'},
#                        {'category': 'kickReturnYards', 'stat': '49'},
#                        {'category': 'kickReturnTDs', 'stat': '0'},
#                        {'category': 'kickReturns', 'stat': '3'},
#                        {'category': 'kickingPoints', 'stat': '7'},
#                        {'category': 'interceptionYards', 'stat': '14'},
#                        {'category': 'interceptionTDs', 'stat': '0'},
#                        {'category': 'passesIntercepted', 'stat': '3'},
#                        {'category': 'fumblesRecovered', 'stat': '1'},
#                        {'category': 'totalFumbles', 'stat': '0'},
#                        {'category': 'tacklesForLoss', 'stat': '5'},
#                        {'category': 'defensiveTDs', 'stat': '0'},
#                        {'category': 'tackles', 'stat': '38'},
#                        {'category': 'sacks', 'stat': '3'},
#                        {'category': 'qbHurries', 'stat': '5'},
#                        {'category': 'passesDeflected', 'stat': '3'},
#                        {'category': 'possessionTime', 'stat': '30:42'},
#                        {'category': 'interceptions', 'stat': '1'},
#                        {'category': 'fumblesLost', 'stat': '0'},
#                        {'category': 'turnovers', 'stat': '1'},
#                        {'category': 'totalPenaltiesYards', 'stat': '3-25'},
#                        {'category': 'yardsPerRushAttempt', 'stat': '2.2'},
#                        {'category': 'rushingAttempts', 'stat': '25'},
#                        {'category': 'rushingYards', 'stat': '55'},
#                        {'category': 'yardsPerPass', 'stat': '4.5'},
#                        {'category': 'completionAttempts', 'stat': '24-44'},
#                        {'category': 'netPassingYards', 'stat': '196'},
#                        {'category': 'totalYards', 'stat': '251'},
#                        {'category': 'fourthDownEff', 'stat': '2-2'},
#                        {'category': 'thirdDownEff', 'stat': '8-17'},
#                        {'category': 'firstDowns', 'stat': '20'}]}]}]

# %%
con=sqlite3.connect('collegeFootball.db')
cursor_obj= con.cursor()
cursor_obj.execute("DROP TABLE IF EXISTS teamStats23")
allWks.to_sql(name='teamStats23',con=con)
con.commit()
con.close()

# %%
allWks=pd.concat([extract_team_data(year=2023,week=i) for i in range(1,2)])

# %%
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = api_key
configuration.api_key_prefix['Authorization']='Bearer'
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))

# %%
con=sqlite3.connect('collegeFootball.db')
cursor_obj= con.cursor()
cursor_obj.execute("DROP TABLE IF EXISTS teamStats23")
# Out:
#       game_id  team_id         team_name home_away  points rushingTDs  \
# 0   401540244     2320             Lamar      home      17          1
# 1   401540244       70             Idaho      away      42          2
# 2   401525434     2426              Navy      away       3          0
# 3   401525434       87        Notre Dame      home      42          2
# 4   401525435     2634   Tennessee State      away       3          0
# ..        ...      ...               ...       ...     ...        ...
# 17  401539480      130          Michigan      away      26          2
# 18  401539476      166  New Mexico State      away      35          1
# 19  401539476     2335           Liberty      home      49          5
# 0   401520445     2426              Navy      away      11          0
# 1   401520445      349              Army      home      17          0
#
#    passingTDs kickReturnYards kickReturnTDs kickReturns  ... firstDowns  \
# 0           1              82             0           4  ...         16
# 1           4               0             0           1  ...         20
# 2           0              12             0           1  ...         12
# 3           4              41             0           2  ...         27
# 4           0              76             0           2  ...         12
# ..        ...             ...           ...         ...  ...        ...
# 17          0             NaN           NaN         NaN  ...         12
# 18          4              44             0           3  ...         28
# 19          2              78             0           4  ...         34
# 0           1              39             0           1  ...         17
# 1           1              27             0           3  ...         15
#
#    puntReturnYards puntReturnTDs puntReturns tacklesForLoss defensiveTDs  \
# 0              NaN           NaN         NaN            NaN          NaN
# 1               26             0           3            NaN          NaN
# 2              NaN           NaN         NaN              2            0
# 3               11             0           1              5            0
# 4              NaN           NaN         NaN              6            0
# ..             ...           ...         ...            ...          ...
# 17              87             0           1              5            0
# 18             NaN           NaN         NaN              1            0
# 19               1             0           1              3            0
# 0              NaN           NaN         NaN            NaN          NaN
# 1                3             0           2            NaN          NaN
#
#    tackles sacks qbHurries passesDeflected
# 0      NaN   NaN       NaN             NaN
# 1      NaN   NaN       NaN             NaN
# 2       42     0         1               2
# 3       41     2         2               0
# 4       45     0         1               1
# ..     ...   ...       ...             ...
# 17      27     4         5               8
# 18      37     0         1               1
# 19      30     0         3               7
# 0      NaN   NaN       NaN             NaN
# 1      NaN   NaN       NaN             NaN
#
# [2980 rows x 40 columns]

# %%
p3=pd.read_sql('SELECT * FROM teamStats23;',con)

# %%
p3.loc[p3.team_name=='Ohio State']
# Out:
#       index    game_id  team_id   team_name home_away  points rushingTDs  \
# 245     245  401520156      194  Ohio State      away      23          2
# 489     229  401520208      194  Ohio State      home      35          2
# 598      94  401520240      194  Ohio State      home      63          3
# 746       2  401521330      194  Ohio State      away      17          2
# 1375    161  401520307      194  Ohio State      home      37          1
# 1597    179  401520323      194  Ohio State      away      41          2
# 1805    169  401520343      194  Ohio State      home      20          1
# 2035    183  401520360      194  Ohio State      away      24          1
# 2275    197  401520375      194  Ohio State      away      35          1
# 2527    201  401520393      194  Ohio State      home      38          2
# 2779    205  401520415      194  Ohio State      home      37          2
# 2939    115  401520434      194  Ohio State      away      24          1
#
#      passingTDs kickReturnYards kickReturnTDs  ... firstDowns puntReturnYards  \
# 245           0              23             0  ...         22              14
# 489           3              40             0  ...         23               3
# 598           4              40             0  ...         24              18
# 746           0              32             0  ...         19               8
# 1375          2              24             0  ...         19              -3
# 1597          4              49             0  ...         24               0
# 1805          1              14             0  ...         22              16
# 2035          2            None          None  ...         23               6
# 2275          3              -5             0  ...         15            None
# 2527          3            None          None  ...         25              11
# 2779          2            None          None  ...         23            None
# 2939          2              42             0  ...         21            None
#
#      puntReturnTDs puntReturns tacklesForLoss defensiveTDs tackles sacks  \
# 245              0           2              6            0      34     1
# 489              0           2              3            0      36     2
# 598              0           1              8            1      38     2
# 746              0           1              2            0      36     0
# 1375             0           3              5            1      36     2
# 1597             0           1              9            0      35     3
# 1805             0           4              6            0      31     4
# 2035             0           1              4            0      27     2
# 2275          None        None              4            1      21     1
# 2527             0           1              6            0      30     2
# 2779          None        None              7            0      28     2
# 2939          None        None              2            0      33     1
#
#      qbHurries passesDeflected
# 245          0               4
# 489          0               2
# 598          2               6
# 746          3               5
# 1375         5               5
# 1597         1               5
# 1805         4               6
# 2035         1               4
# 2275         0               4
# 2527         0               5
# 2779         1               1
# 2939         2               0
#
# [12 rows x 41 columns]

# %%
p3.loc[p3.game_id==401540244]
# Out:
#    index    game_id  team_id team_name home_away  points rushingTDs  \
# 0      0  401540244     2320     Lamar      home      17          1
# 1      1  401540244       70     Idaho      away      42          2
#
#   passingTDs kickReturnYards kickReturnTDs  ... firstDowns puntReturnYards  \
# 0          1              82             0  ...         16            None
# 1          4               0             0  ...         20              26
#
#   puntReturnTDs puntReturns tacklesForLoss defensiveTDs tackles sacks  \
# 0          None        None           None         None    None  None
# 1             0           3           None         None    None  None
#
#   qbHurries passesDeflected
# 0      None            None
# 1      None            None
#
# [2 rows x 41 columns]
